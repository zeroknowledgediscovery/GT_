# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pylab as plt
# %matplotlib inline

# %%
mf=pd.read_csv('model_u0_mean_.csv')

# %%
mf['src_']=[x.split('#')[-1] for x in mf.src]
mf['tgt_']=[x.split('#')[-1] for x in mf.tgt]

# %%
mf.src_.value_counts().index
# Out:
# Index(['popFrac', 'Dist', 'visitors', 'singles', 'MeetFrac', 'meetingPairs',
#        'SiteTypeRestaurant', 'SiteTypeRecreationalSite', 'fracFriends',
#        'myFriends', 'myFriendsR', 'src'],
#       dtype='object')

# %%
mf=mf[['src_','tgt_','delay','gamma','mass']]

# %%
mf_mean=mf.groupby(['src_','tgt_']).mean().reset_index()

# %%
HIGAMMA=.99
VAR='myFriendsR'
gf=mf[(mf.tgt_==VAR) & (mf.gamma>HIGAMMA) ]
D1=26
D2=52
D3=100
XX=VAR

mf_mean[mf_mean.tgt_==VAR]

sf=gf[(gf.delay.between(0,D1)) & ~(gf.src_==XX)].groupby('src_').median()
sf['Count']=gf[(gf.delay.between(0,D1)) & ~(gf.src_==XX)].src_.value_counts()
print(sf.sort_values('gamma',ascending=False))
print(gf[(gf.delay.between(0,D1)) & ~(gf.src_==XX)].sort_values('src_'))

sf=gf[(gf.delay.between(D1+1,D2)) & ~(gf.src_==XX)].groupby('src_').median()
sf['Count']=gf[(gf.delay.between(D1+1,D2)) & ~(gf.src_==XX)].src_.value_counts()
print(sf.sort_values('gamma',ascending=False))
print(gf[(gf.delay.between(D1+1,D2)) & ~(gf.src_==XX)].sort_values('src_'))

sf=gf[(gf.delay.between(D2+1,D3)) & ~(gf.src_==XX)].groupby('src_').median()
sf['Count']=gf[(gf.delay.between(D2+1,D3)) & ~(gf.src_==XX)].src_.value_counts()
print(sf.sort_values('gamma',ascending=False))
print(gf[(gf.delay.between(D2+1,D3)) & ~(gf.src_==XX)].sort_values('src_'))
# Out:
#               delay  gamma  mass  Count
# src_
# Dist             11    1.0   0.0     18
# MeetFrac          1    1.0   0.0      2
# fracFriends       1    1.0   0.0      1
# meetingPairs      1    1.0   0.0      1
# myFriends         1    1.0   0.0      1
# popFrac          12    1.0   0.0      7
# singles          14    1.0   0.0      3
# visitors         15    1.0   0.0      2
#                 src_        tgt_  delay  gamma          mass
# 615991          Dist  myFriendsR     11    1.0  0.000000e+00
# 615682          Dist  myFriendsR     11    1.0  0.000000e+00
# 615082          Dist  myFriendsR     12    1.0  0.000000e+00
# 614761          Dist  myFriendsR      8    1.0  0.000000e+00
# 603206          Dist  myFriendsR     17    1.0  0.000000e+00
# 601582          Dist  myFriendsR      9    1.0  0.000000e+00
# 600357          Dist  myFriendsR      4    1.0  0.000000e+00
# 600355          Dist  myFriendsR     14    1.0  0.000000e+00
# 495544          Dist  myFriendsR      3    1.0  0.000000e+00
# 495541          Dist  myFriendsR      1    1.0  0.000000e+00
# 601014          Dist  myFriendsR     18    1.0  0.000000e+00
# 495214          Dist  myFriendsR     20    1.0  0.000000e+00
# 493232          Dist  myFriendsR     18    1.0  0.000000e+00
# 493233          Dist  myFriendsR     24    1.0 -1.192090e-08
# 493236          Dist  myFriendsR      5    1.0  0.000000e+00
# 493280          Dist  myFriendsR     22    1.0  0.000000e+00
# 493279          Dist  myFriendsR      2    1.0  0.000000e+00
# 615279          Dist  myFriendsR      3    1.0  0.000000e+00
# 615198      MeetFrac  myFriendsR      1    1.0  0.000000e+00
# 615866      MeetFrac  myFriendsR      1    1.0  0.000000e+00
# 615201   fracFriends  myFriendsR      1    1.0  0.000000e+00
# 615869  meetingPairs  myFriendsR      1    1.0  0.000000e+00
# 615210     myFriends  myFriendsR      1    1.0  0.000000e+00
# 601032       popFrac  myFriendsR     18    1.0  0.000000e+00
# 601591       popFrac  myFriendsR      9    1.0  0.000000e+00
# 495237       popFrac  myFriendsR     20    1.0  0.000000e+00
# 493331       popFrac  myFriendsR      2    1.0  0.000000e+00
# 615088       popFrac  myFriendsR     12    1.0  0.000000e+00
# 493332       popFrac  myFriendsR     22    1.0  0.000000e+00
# 615281       popFrac  myFriendsR      3    1.0  0.000000e+00
# 282106       singles  myFriendsR     14    1.0  2.483530e-09
# 615090       singles  myFriendsR     12    1.0  0.000000e+00
# 601036       singles  myFriendsR     18    1.0  0.000000e+00
# 615092      visitors  myFriendsR     12    1.0  0.000000e+00
# 601041      visitors  myFriendsR     18    1.0  0.000000e+00
#               delay  gamma  mass  Count
# src_
# Dist             40    1.0   0.0     13
# MeetFrac         46    1.0   0.0      5
# fracFriends      51    1.0   0.0      3
# meetingPairs     49    1.0   0.0      2
# myFriends        51    1.0   0.0      3
# popFrac          38    1.0   0.0      9
# singles          41    1.0   0.0      1
# visitors         41    1.0   0.0      1
#                 src_        tgt_  delay     gamma          mass
# 601579          Dist  myFriendsR     32  1.000000  0.000000e+00
# 601514          Dist  myFriendsR     37  1.000000  0.000000e+00
# 603207          Dist  myFriendsR     40  1.000000  0.000000e+00
# 601015          Dist  myFriendsR     41  1.000000  0.000000e+00
# 600356          Dist  myFriendsR     37  1.000000  0.000000e+00
# 601515          Dist  myFriendsR     38  1.000000  0.000000e+00
# 615280          Dist  myFriendsR     51  1.000000  0.000000e+00
# 495547          Dist  myFriendsR     50  1.000000  0.000000e+00
# 493286          Dist  myFriendsR     49  1.000000  0.000000e+00
# 493283          Dist  myFriendsR     38  1.000000  0.000000e+00
# 493281          Dist  myFriendsR     28  1.000000 -2.384190e-08
# 493235          Dist  myFriendsR     48  1.000000  0.000000e+00
# 601580          Dist  myFriendsR     52  1.000000  0.000000e+00
# 703065      MeetFrac  myFriendsR     28  0.990143  0.000000e+00
# 615199      MeetFrac  myFriendsR     49  1.000000  0.000000e+00
# 601583      MeetFrac  myFriendsR     52  1.000000  0.000000e+00
# 615867      MeetFrac  myFriendsR     46  1.000000  0.000000e+00
# 279157      MeetFrac  myFriendsR     46  1.000000  0.000000e+00
# 782182   fracFriends  myFriendsR     51  1.000000  0.000000e+00
# 601584   fracFriends  myFriendsR     52  1.000000  0.000000e+00
# 615202   fracFriends  myFriendsR     49  1.000000  0.000000e+00
# 615870  meetingPairs  myFriendsR     46  1.000000  0.000000e+00
# 601585  meetingPairs  myFriendsR     52  1.000000  0.000000e+00
# 615211     myFriends  myFriendsR     49  1.000000  0.000000e+00
# 782189     myFriends  myFriendsR     51  1.000000  0.000000e+00
# 601587     myFriends  myFriendsR     52  1.000000  0.000000e+00
# 601589       popFrac  myFriendsR     52  1.000000  0.000000e+00
# 601567       popFrac  myFriendsR     38  1.000000  0.000000e+00
# 493337       popFrac  myFriendsR     49  1.000000  0.000000e+00
# 615282       popFrac  myFriendsR     51  1.000000  0.000000e+00
# 493335       popFrac  myFriendsR     38  1.000000  0.000000e+00
# 601566       popFrac  myFriendsR     37  1.000000  0.000000e+00
# 493333       popFrac  myFriendsR     28  1.000000 -2.384190e-08
# 601588       popFrac  myFriendsR     32  1.000000  0.000000e+00
# 601033       popFrac  myFriendsR     41  1.000000  0.000000e+00
# 601037       singles  myFriendsR     41  1.000000  0.000000e+00
# 601042      visitors  myFriendsR     41  1.000000  0.000000e+00
#               delay     gamma  mass  Count
# src_
# Dist           76.0  1.000000   0.0     24
# MeetFrac       74.0  1.000000   0.0      3
# meetingPairs   75.0  1.000000   0.0      1
# popFrac        75.0  1.000000   0.0     11
# singles        66.0  1.000000   0.0      4
# visitors       66.0  1.000000   0.0      4
# myFriends      62.5  0.999993   0.0      2
# fracFriends    67.0  0.999987   0.0      1
#                 src_        tgt_  delay     gamma          mass
# 493237          Dist  myFriendsR     57  1.000000 -9.934110e-09
# 615268          Dist  myFriendsR     66  1.000000  0.000000e+00
# 615083          Dist  myFriendsR     60  1.000000  0.000000e+00
# 614760          Dist  myFriendsR     56  1.000000  0.000000e+00
# 603905          Dist  myFriendsR     88  1.000000  0.000000e+00
# 603209          Dist  myFriendsR     88  1.000000  0.000000e+00
# 601581          Dist  myFriendsR     80  1.000000  0.000000e+00
# 601518          Dist  myFriendsR     87  1.000000  0.000000e+00
# 615683          Dist  myFriendsR     59  1.000000  0.000000e+00
# 601516          Dist  myFriendsR     75  1.000000  0.000000e+00
# 601447          Dist  myFriendsR     89  1.000000  0.000000e+00
# 601017          Dist  myFriendsR     89  1.000000  0.000000e+00
# 601016          Dist  myFriendsR     66  1.000000  0.000000e+00
# 601517          Dist  myFriendsR     76  1.000000  0.000000e+00
# 496761          Dist  myFriendsR     96  1.000000  1.192090e-08
# 493239          Dist  myFriendsR     70  1.000000  0.000000e+00
# 493241          Dist  myFriendsR     97  1.000000  0.000000e+00
# 493288          Dist  myFriendsR     64  1.000000  0.000000e+00
# 493289          Dist  myFriendsR     68  0.999999  8.514950e-09
# 493290          Dist  myFriendsR     76  1.000000  0.000000e+00
# 600359          Dist  myFriendsR     85  1.000000  0.000000e+00
# 496756          Dist  myFriendsR     78  1.000000  1.192090e-08
# 615992          Dist  myFriendsR     59  1.000000  0.000000e+00
# 496760          Dist  myFriendsR     91  1.000000  1.192090e-08
# 601398      MeetFrac  myFriendsR     55  1.000000  0.000000e+00
# 615200      MeetFrac  myFriendsR     98  1.000000  0.000000e+00
# 605124      MeetFrac  myFriendsR     74  1.000000  1.986820e-08
# 615270   fracFriends  myFriendsR     67  0.999987  0.000000e+00
# 601540  meetingPairs  myFriendsR     75  1.000000  0.000000e+00
# 615272     myFriends  myFriendsR     67  0.999987  0.000000e+00
# 602300     myFriends  myFriendsR     58  1.000000  0.000000e+00
# 615273       popFrac  myFriendsR     66  1.000000  0.000000e+00
# 601034       popFrac  myFriendsR     66  1.000000  0.000000e+00
# 615089       popFrac  myFriendsR     60  1.000000  0.000000e+00
# 601035       popFrac  myFriendsR     89  1.000000  0.000000e+00
# 601590       popFrac  myFriendsR     80  1.000000  0.000000e+00
# 493339       popFrac  myFriendsR     64  1.000000  0.000000e+00
# 601571       popFrac  myFriendsR     87  1.000000  0.000000e+00
# 601570       popFrac  myFriendsR     76  1.000000  0.000000e+00
# 601569       popFrac  myFriendsR     75  1.000000  0.000000e+00
# 493340       popFrac  myFriendsR     68  0.999999  8.514950e-09
# 493341       popFrac  myFriendsR     76  1.000000  0.000000e+00
# 615091       singles  myFriendsR     60  1.000000  0.000000e+00
# 615275       singles  myFriendsR     66  1.000000  0.000000e+00
# 601040       singles  myFriendsR     89  1.000000  0.000000e+00
# 601039       singles  myFriendsR     66  1.000000  0.000000e+00
# 601043      visitors  myFriendsR     66  1.000000  0.000000e+00
# 601044      visitors  myFriendsR     89  1.000000  0.000000e+00
# 615093      visitors  myFriendsR     60  1.000000  0.000000e+00
# 615277      visitors  myFriendsR     66  1.000000  0.000000e+00

# %%
HIGAMMA=.7
VAR='visitors'
gf=mf[(mf.tgt_==VAR) & (mf.gamma>HIGAMMA) ]
D1=26
D2=52
D3=100
XX=VAR

mf_mean[mf_mean.tgt_==VAR]

sf=gf[(gf.delay.between(0,D1)) & ~(gf.src_==XX)].groupby('src_').median()
sf['Count']=gf[(gf.delay.between(0,D1)) & ~(gf.src_==XX)].src_.value_counts()
print(sf.sort_values('gamma',ascending=False))
print(gf[(gf.delay.between(0,D1)) & ~(gf.src_==XX)].sort_values('src_'))

sf=gf[(gf.delay.between(D1+1,D2)) & ~(gf.src_==XX)].groupby('src_').median()
sf['Count']=gf[(gf.delay.between(D1+1,D2)) & ~(gf.src_==XX)].src_.value_counts()
print(sf.sort_values('gamma',ascending=False))
print(gf[(gf.delay.between(D1+1,D2)) & ~(gf.src_==XX)].sort_values('src_'))

sf=gf[(gf.delay.between(D2+1,D3)) & ~(gf.src_==XX)].groupby('src_').median()
sf['Count']=gf[(gf.delay.between(D2+1,D3)) & ~(gf.src_==XX)].src_.value_counts()
print(sf.sort_values('gamma',ascending=False))
print(gf[(gf.delay.between(D2+1,D3)) & ~(gf.src_==XX)].sort_values('src_'))
# Out:
#               delay     gamma      mass  Count
# src_
# meetingPairs   13.5  0.870528 -0.018588      2
# MeetFrac        3.0  0.778964  0.034385      3
# singles         4.5  0.754292  0.400490      4
# fracFriends     5.0  0.741724  0.161381      3
# myFriends       5.0  0.735325  0.151823      3
# myFriendsR      5.0  0.735325  0.151823      3
# popFrac         3.0  0.730742 -0.027236      6
# Dist            3.0  0.715237  0.418729      4
#                  src_      tgt_  delay     gamma      mass
# 4987289          Dist  visitors      1  0.728743  0.323159
# 4269380          Dist  visitors      3  0.736361  0.420117
# 4043747          Dist  visitors      3  0.700561  0.417341
# 4054079          Dist  visitors      4  0.701732  0.707148
# 4727080      MeetFrac  visitors      1  0.739648  0.041429
# 4034137      MeetFrac  visitors     24  0.956546  0.034385
# 4267477      MeetFrac  visitors      3  0.778964 -0.061115
# 4269944   fracFriends  visitors      5  0.736354  0.186926
# 4265621   fracFriends  visitors      3  0.741724  0.161381
# 4031456   fracFriends  visitors     26  0.965492  0.047024
# 4267484  meetingPairs  visitors      3  0.784583 -0.053903
# 4034148  meetingPairs  visitors     24  0.956473  0.016727
# 4269963     myFriends  visitors      5  0.735325  0.186926
# 4031484     myFriends  visitors     26  0.988126 -0.001537
# 4265648     myFriends  visitors      3  0.728308  0.151823
# 4265643    myFriendsR  visitors      3  0.728764  0.151823
# 4269957    myFriendsR  visitors      5  0.735325  0.186926
# 4031476    myFriendsR  visitors     26  0.987836 -0.001537
# 4266755       popFrac  visitors      4  0.777130 -0.246139
# 4043816       popFrac  visitors      3  0.703547  0.461559
# 4262574       popFrac  visitors      3  0.725797  0.136968
# 4269423       popFrac  visitors      3  0.735687  0.420117
# 4261961       popFrac  visitors      1  0.701709 -0.204118
# 4266752       popFrac  visitors      3  0.765634 -0.191441
# 4266766       singles  visitors      5  0.757717  0.491232
# 4834635       singles  visitors      7  0.860924 -0.000131
# 4269441       singles  visitors      3  0.750866  0.365822
# 4265558       singles  visitors      4  0.712122  0.435159
#               delay     gamma      mass  Count
# src_
# Dist             42  0.807516  0.039390      2
# popFrac          43  0.799760  0.010862      3
# myFriendsR       51  0.780922 -0.019155      1
# fracFriends      51  0.779125 -0.019155      1
# myFriends        51  0.769863 -0.019155      1
# meetingPairs     42  0.762304 -0.043271      1
#                  src_      tgt_  delay     gamma      mass
# 4593080          Dist  visitors     41  0.833565  0.013892
# 4760504          Dist  visitors     43  0.781466  0.064888
# 4746336   fracFriends  visitors     51  0.779125 -0.019155
# 4457789  meetingPairs  visitors     42  0.762304 -0.043271
# 4746350     myFriends  visitors     51  0.769863 -0.019155
# 4746348    myFriendsR  visitors     51  0.780922 -0.019155
# 4760524       popFrac  visitors     42  0.797861  0.010862
# 4760525       popFrac  visitors     43  0.799760  0.065102
# 4892686       popFrac  visitors     52  0.954552  0.002892
#               delay     gamma      mass  Count
# src_
# singles        89.0  0.897585  0.034478      2
# meetingPairs   86.0  0.849528  0.033333      1
# popFrac        88.0  0.834004  0.061111      1
# myFriends      84.0  0.778961  0.000000      3
# myFriendsR     84.0  0.776091  0.000000      3
# fracFriends    84.0  0.774161  0.000000      3
# Dist           85.5  0.768857  0.041088      2
#                  src_      tgt_  delay     gamma      mass
# 4587541          Dist  visitors     88  0.834004  0.061111
# 4969613          Dist  visitors     83  0.703711  0.021066
# 4029936   fracFriends  visitors     84  0.773060  0.012631
# 4770920   fracFriends  visitors     86  0.932105  0.000000
# 4883380   fracFriends  visitors     84  0.774161 -0.004634
# 4566264  meetingPairs  visitors     86  0.849528  0.033333
# 4029954     myFriends  visitors     84  0.778961  0.012631
# 4770934     myFriends  visitors     86  0.932134  0.000000
# 4883405     myFriends  visitors     84  0.777981 -0.004634
# 4029952    myFriendsR  visitors     84  0.771072  0.012631
# 4770931    myFriendsR  visitors     86  0.932120  0.000000
# 4883398    myFriendsR  visitors     84  0.776091 -0.004634
# 4587562       popFrac  visitors     88  0.834004  0.061111
# 4023054       singles  visitors     90  0.961165  0.007845
# 4587566       singles  visitors     88  0.834004  0.061111

# %%
HIGAMMA=.7
VAR='Dist'
gf=mf[(mf.tgt_==VAR) & (mf.gamma>HIGAMMA) ]
D1=26
D2=52
D3=100
XX=VAR

mf_mean[mf_mean.tgt_==VAR]

sf=gf[(gf.delay.between(0,D1)) & ~(gf.src_==XX)].groupby('src_').median()
sf['Count']=gf[(gf.delay.between(0,D1)) & ~(gf.src_==XX)].src_.value_counts()
print(sf.sort_values('gamma',ascending=False))
print(gf[(gf.delay.between(0,D1)) & ~(gf.src_==XX)].sort_values('src_'))

sf=gf[(gf.delay.between(D1+1,D2)) & ~(gf.src_==XX)].groupby('src_').median()
sf['Count']=gf[(gf.delay.between(D1+1,D2)) & ~(gf.src_==XX)].src_.value_counts()
print(sf.sort_values('gamma',ascending=False))
print(gf[(gf.delay.between(D1+1,D2)) & ~(gf.src_==XX)].sort_values('src_'))

sf=gf[(gf.delay.between(D2+1,D3)) & ~(gf.src_==XX)].groupby('src_').median()
sf['Count']=gf[(gf.delay.between(D2+1,D3)) & ~(gf.src_==XX)].src_.value_counts()
print(sf.sort_values('gamma',ascending=False))
print(gf[(gf.delay.between(D2+1,D3)) & ~(gf.src_==XX)].sort_values('src_'))
# Out:
#           delay     gamma      mass  Count
# src_
# visitors      4  0.780893  0.002404      1
# singles       1  0.741692  0.596172      1
#              src_  tgt_  delay     gamma      mass
# 5259336   singles  Dist      1  0.741692  0.596172
# 5129198  visitors  Dist      4  0.780893  0.002404
#              delay     gamma      mass  Count
# src_
# singles       51.0  0.969737  0.001664      1
# fracFriends   36.5  0.854098 -0.006084      2
# myFriends     36.5  0.853492 -0.006084      2
# myFriendsR    40.0  0.780884 -0.015871      3
# visitors      38.5  0.739200  0.009786      2
#                 src_  tgt_  delay     gamma          mass
# 5929879  fracFriends  Dist     33  0.929111  3.703700e-03
# 6051947  fracFriends  Dist     40  0.779086 -1.587080e-02
# 5929908    myFriends  Dist     33  0.929696  3.703700e-03
# 6051989    myFriends  Dist     40  0.777288 -1.587080e-02
# 5394877   myFriendsR  Dist     48  0.763992 -3.314110e-02
# 5929900   myFriendsR  Dist     33  0.929111  3.703700e-03
# 6051978   myFriendsR  Dist     40  0.780884 -1.587080e-02
# 5638587      singles  Dist     51  0.969737  1.663560e-03
# 5353488     visitors  Dist     46  0.711352 -4.336810e-19
# 5800087     visitors  Dist     31  0.767048  1.957120e-02
#               delay     gamma      mass  Count
# src_
# visitors         98  0.803037  0.047565      1
# meetingPairs     95  0.767721  0.042866      1
#                  src_  tgt_  delay     gamma      mass
# 5487035  meetingPairs  Dist     95  0.767721  0.042866
# 5281599      visitors  Dist     98  0.803037  0.047565

# %%
HIGAMMA=.99
VAR='myFriends'
gf=mf[(mf.tgt_==VAR) & (mf.gamma>HIGAMMA) ]
D1=26
D2=52
D3=100
XX=VAR

mf_mean[mf_mean.tgt_==VAR]

sf=gf[(gf.delay.between(0,D1)) & ~(gf.src_==XX)].groupby('src_').median()
sf['Count']=gf[(gf.delay.between(0,D1)) & ~(gf.src_==XX)].src_.value_counts()
print(sf.sort_values('gamma',ascending=False))
print(gf[(gf.delay.between(0,D1)) & ~(gf.src_==XX)].sort_values('src_'))

sf=gf[(gf.delay.between(D1+1,D2)) & ~(gf.src_==XX)].groupby('src_').median()
sf['Count']=gf[(gf.delay.between(D1+1,D2)) & ~(gf.src_==XX)].src_.value_counts()
print(sf.sort_values('gamma',ascending=False))
print(gf[(gf.delay.between(D1+1,D2)) & ~(gf.src_==XX)].sort_values('src_'))

sf=gf[(gf.delay.between(D2+1,D3)) & ~(gf.src_==XX)].groupby('src_').median()
sf['Count']=gf[(gf.delay.between(D2+1,D3)) & ~(gf.src_==XX)].src_.value_counts()
print(sf.sort_values('gamma',ascending=False))
print(gf[(gf.delay.between(D2+1,D3)) & ~(gf.src_==XX)].sort_values('src_'))
# Out:
#               delay  gamma  mass  Count
# src_
# Dist             11    1.0   0.0     18
# MeetFrac          1    1.0   0.0      2
# fracFriends       1    1.0   0.0      1
# meetingPairs      1    1.0   0.0      1
# myFriendsR        1    1.0   0.0      1
# popFrac          12    1.0   0.0      7
# singles          14    1.0   0.0      3
# visitors         15    1.0   0.0      2
#                  src_       tgt_  delay  gamma          mass
# 5658482          Dist  myFriends     11    1.0  0.000000e+00
# 5658170          Dist  myFriends     11    1.0  0.000000e+00
# 5657569          Dist  myFriends     12    1.0  0.000000e+00
# 5657259          Dist  myFriends      8    1.0  0.000000e+00
# 5447313          Dist  myFriends     17    1.0  0.000000e+00
# 5445670          Dist  myFriends      9    1.0  0.000000e+00
# 5444436          Dist  myFriends      4    1.0  0.000000e+00
# 5444433          Dist  myFriends     14    1.0  0.000000e+00
# 4184642          Dist  myFriends      3    1.0  0.000000e+00
# 4184639          Dist  myFriends      1    1.0  0.000000e+00
# 5445101          Dist  myFriends     18    1.0  0.000000e+00
# 4184326          Dist  myFriends     20    1.0  0.000000e+00
# 4182402          Dist  myFriends     18    1.0  0.000000e+00
# 4182403          Dist  myFriends     24    1.0 -1.192090e-08
# 4182407          Dist  myFriends      5    1.0  0.000000e+00
# 4182442          Dist  myFriends     22    1.0  0.000000e+00
# 4182441          Dist  myFriends      2    1.0  0.000000e+00
# 5657773          Dist  myFriends      3    1.0  0.000000e+00
# 5657687      MeetFrac  myFriends      1    1.0  0.000000e+00
# 5658349      MeetFrac  myFriends      1    1.0  0.000000e+00
# 5657690   fracFriends  myFriends      1    1.0  0.000000e+00
# 5658352  meetingPairs  myFriends      1    1.0  0.000000e+00
# 5657696    myFriendsR  myFriends      1    1.0  0.000000e+00
# 5445117       popFrac  myFriends     18    1.0  0.000000e+00
# 5445679       popFrac  myFriends      9    1.0  0.000000e+00
# 4184352       popFrac  myFriends     20    1.0  0.000000e+00
# 4182488       popFrac  myFriends      2    1.0  0.000000e+00
# 5657575       popFrac  myFriends     12    1.0  0.000000e+00
# 4182489       popFrac  myFriends     22    1.0  0.000000e+00
# 5657775       popFrac  myFriends      3    1.0  0.000000e+00
# 1891385       singles  myFriends     14    1.0  2.483530e-09
# 5657577       singles  myFriends     12    1.0  0.000000e+00
# 5445121       singles  myFriends     18    1.0  0.000000e+00
# 5657579      visitors  myFriends     12    1.0  0.000000e+00
# 5445125      visitors  myFriends     18    1.0  0.000000e+00
#               delay  gamma  mass  Count
# src_
# Dist           40.0    1.0   0.0     13
# MeetFrac       47.5    1.0   0.0      4
# fracFriends    51.0    1.0   0.0      3
# meetingPairs   49.0    1.0   0.0      2
# myFriendsR     51.0    1.0   0.0      3
# popFrac        38.0    1.0   0.0      9
# singles        41.0    1.0   0.0      1
# visitors       41.0    1.0   0.0      1
#                  src_       tgt_  delay  gamma          mass
# 5444435          Dist  myFriends     37    1.0  0.000000e+00
# 5447314          Dist  myFriends     40    1.0  0.000000e+00
# 5445597          Dist  myFriends     38    1.0  0.000000e+00
# 5445596          Dist  myFriends     37    1.0  0.000000e+00
# 5445102          Dist  myFriends     41    1.0  0.000000e+00
# 5445667          Dist  myFriends     32    1.0  0.000000e+00
# 4184646          Dist  myFriends     50    1.0  0.000000e+00
# 5445668          Dist  myFriends     52    1.0  0.000000e+00
# 4182447          Dist  myFriends     49    1.0  0.000000e+00
# 4182444          Dist  myFriends     38    1.0  0.000000e+00
# 4182443          Dist  myFriends     28    1.0 -2.384190e-08
# 4182406          Dist  myFriends     48    1.0  0.000000e+00
# 5657774          Dist  myFriends     51    1.0  0.000000e+00
# 5658350      MeetFrac  myFriends     46    1.0  0.000000e+00
# 5445671      MeetFrac  myFriends     52    1.0  0.000000e+00
# 5657688      MeetFrac  myFriends     49    1.0  0.000000e+00
# 1888427      MeetFrac  myFriends     46    1.0  0.000000e+00
# 5445672   fracFriends  myFriends     52    1.0  0.000000e+00
# 5657691   fracFriends  myFriends     49    1.0  0.000000e+00
# 7481207   fracFriends  myFriends     51    1.0  0.000000e+00
# 5445673  meetingPairs  myFriends     52    1.0  0.000000e+00
# 5658353  meetingPairs  myFriends     46    1.0  0.000000e+00
# 5657697    myFriendsR  myFriends     49    1.0  0.000000e+00
# 7481213    myFriendsR  myFriends     51    1.0  0.000000e+00
# 5445674    myFriendsR  myFriends     52    1.0  0.000000e+00
# 5445676       popFrac  myFriends     32    1.0  0.000000e+00
# 5445677       popFrac  myFriends     52    1.0  0.000000e+00
# 5445650       popFrac  myFriends     37    1.0  0.000000e+00
# 5445118       popFrac  myFriends     41    1.0  0.000000e+00
# 4182494       popFrac  myFriends     49    1.0  0.000000e+00
# 5657776       popFrac  myFriends     51    1.0  0.000000e+00
# 4182491       popFrac  myFriends     38    1.0  0.000000e+00
# 4182490       popFrac  myFriends     28    1.0 -2.384190e-08
# 5445651       popFrac  myFriends     38    1.0  0.000000e+00
# 5445122       singles  myFriends     41    1.0  0.000000e+00
# 5445126      visitors  myFriends     41    1.0  0.000000e+00
#               delay     gamma  mass  Count
# src_
# Dist           76.0  1.000000   0.0     24
# MeetFrac       74.0  1.000000   0.0      3
# meetingPairs   75.0  1.000000   0.0      1
# popFrac        75.0  1.000000   0.0     11
# singles        66.0  1.000000   0.0      4
# visitors       66.0  1.000000   0.0      4
# myFriendsR     62.5  0.999993   0.0      2
# fracFriends    67.0  0.999987   0.0      1
#                  src_       tgt_  delay     gamma          mass
# 4182408          Dist  myFriends     57  1.000000 -9.934110e-09
# 5657762          Dist  myFriends     66  1.000000  0.000000e+00
# 5657570          Dist  myFriends     60  1.000000  0.000000e+00
# 5657258          Dist  myFriends     56  1.000000  0.000000e+00
# 5448038          Dist  myFriends     88  1.000000  0.000000e+00
# 5447316          Dist  myFriends     88  1.000000  0.000000e+00
# 5445669          Dist  myFriends     80  1.000000  0.000000e+00
# 5445600          Dist  myFriends     87  1.000000  0.000000e+00
# 5658171          Dist  myFriends     59  1.000000  0.000000e+00
# 5445598          Dist  myFriends     75  1.000000  0.000000e+00
# 5445529          Dist  myFriends     89  1.000000  0.000000e+00
# 5445104          Dist  myFriends     89  1.000000  0.000000e+00
# 5445103          Dist  myFriends     66  1.000000  0.000000e+00
# 5445599          Dist  myFriends     76  1.000000  0.000000e+00
# 4185892          Dist  myFriends     96  1.000000  1.192090e-08
# 4182409          Dist  myFriends     70  1.000000  0.000000e+00
# 4182411          Dist  myFriends     97  1.000000  0.000000e+00
# 4182448          Dist  myFriends     64  1.000000  0.000000e+00
# 4182449          Dist  myFriends     68  0.999999  8.514950e-09
# 4182450          Dist  myFriends     76  1.000000  0.000000e+00
# 5444438          Dist  myFriends     85  1.000000  0.000000e+00
# 4185889          Dist  myFriends     78  1.000000  1.192090e-08
# 5658484          Dist  myFriends     59  1.000000  0.000000e+00
# 4185891          Dist  myFriends     91  1.000000  1.192090e-08
# 5445477      MeetFrac  myFriends     55  1.000000  0.000000e+00
# 5657689      MeetFrac  myFriends     98  1.000000  0.000000e+00
# 5449280      MeetFrac  myFriends     74  1.000000  1.986820e-08
# 5657764   fracFriends  myFriends     67  0.999987  0.000000e+00
# 5445624  meetingPairs  myFriends     75  1.000000  0.000000e+00
# 5657765    myFriendsR  myFriends     67  0.999987  0.000000e+00
# 5446394    myFriendsR  myFriends     58  1.000000  0.000000e+00
# 5657767       popFrac  myFriends     66  1.000000  0.000000e+00
# 5445119       popFrac  myFriends     66  1.000000  0.000000e+00
# 5657576       popFrac  myFriends     60  1.000000  0.000000e+00
# 5445120       popFrac  myFriends     89  1.000000  0.000000e+00
# 5445678       popFrac  myFriends     80  1.000000  0.000000e+00
# 4182495       popFrac  myFriends     64  1.000000  0.000000e+00
# 5445654       popFrac  myFriends     87  1.000000  0.000000e+00
# 5445653       popFrac  myFriends     76  1.000000  0.000000e+00
# 5445652       popFrac  myFriends     75  1.000000  0.000000e+00
# 4182496       popFrac  myFriends     68  0.999999  8.514950e-09
# 4182497       popFrac  myFriends     76  1.000000  0.000000e+00
# 5657578       singles  myFriends     60  1.000000  0.000000e+00
# 5657769       singles  myFriends     66  1.000000  0.000000e+00
# 5445124       singles  myFriends     89  1.000000  0.000000e+00
# 5445123       singles  myFriends     66  1.000000  0.000000e+00
# 5445127      visitors  myFriends     66  1.000000  0.000000e+00
# 5445128      visitors  myFriends     89  1.000000  0.000000e+00
# 5657580      visitors  myFriends     60  1.000000  0.000000e+00
# 5657771      visitors  myFriends     66  1.000000  0.000000e+00

# %%
HIGAMMA=.7
VAR='popFrac'
gf=mf[(mf.tgt_==VAR) & (mf.gamma>HIGAMMA) ]
D1=26
D2=52
D3=100
XX=VAR

mf_mean[mf_mean.tgt_==VAR]

sf=gf[(gf.delay.between(0,D1)) & ~(gf.src_==XX)].groupby('src_').median()
sf['Count']=gf[(gf.delay.between(0,D1)) & ~(gf.src_==XX)].src_.value_counts()
print(sf.sort_values('gamma',ascending=False))
print(gf[(gf.delay.between(0,D1)) & ~(gf.src_==XX)].sort_values('src_'))

sf=gf[(gf.delay.between(D1+1,D2)) & ~(gf.src_==XX)].groupby('src_').median()
sf['Count']=gf[(gf.delay.between(D1+1,D2)) & ~(gf.src_==XX)].src_.value_counts()
print(sf.sort_values('gamma',ascending=False))
print(gf[(gf.delay.between(D1+1,D2)) & ~(gf.src_==XX)].sort_values('src_'))

sf=gf[(gf.delay.between(D2+1,D3)) & ~(gf.src_==XX)].groupby('src_').median()
sf['Count']=gf[(gf.delay.between(D2+1,D3)) & ~(gf.src_==XX)].src_.value_counts()
print(sf.sort_values('gamma',ascending=False))
print(gf[(gf.delay.between(D2+1,D3)) & ~(gf.src_==XX)].sort_values('src_'))
# Out:
#          delay     gamma      mass  Count
# src_
# Dist         8  0.875575  0.296009      2
# singles      1  0.709968  0.132906      1
#             src_     tgt_  delay     gamma      mass
# 6658622     Dist  popFrac      4  0.876287  0.587120
# 6975190     Dist  popFrac     12  0.874862  0.004898
# 6243076  singles  popFrac      1  0.709968  0.132906
#          delay     gamma      mass  Count
# src_
# singles     51  0.969893  0.001664      1
#             src_     tgt_  delay     gamma      mass
# 6705057  singles  popFrac     51  0.969893  0.001664
#              delay     gamma     mass  Count
# src_
# fracFriends     86  0.932166  0.00000      1
# myFriends       86  0.932160  0.00000      1
# visitors        97  0.762000  0.03539      1
#                 src_     tgt_  delay     gamma     mass
# 6904055  fracFriends  popFrac     86  0.932166  0.00000
# 6904067    myFriends  popFrac     86  0.932160  0.00000
# 6815544     visitors  popFrac     97  0.762000  0.03539

# %%
mf_=mf.sample(200000)
#plt.scatter(mf_.mass.values,mf_.gamma.values,c=mf_.delay.values,cmap='jet',alpha=.5)

# %%
ax=mf_.sort_values('delay').set_index('delay').gamma.plot()
mf_.sort_values('delay').set_index('delay').mass.plot(ax=ax)

# %%
PREF=''
df=mf_
df['theta']=np.arccos(df.mass)*2 - (np.pi)
df=df[['gamma','theta','delay']]
df=df[df.delay.between(1,800)]
df=df.sort_values('delay')

fig=plt.figure(figsize=[10,25])
ax = plt.subplot(111, projection='polar')
sf=plt.scatter(1*df.theta.values,df.gamma.values,c=df.delay.values,s=70,cmap='jet',alpha=.5)
plt.colorbar(sf, fraction=0.046, pad=0.04)
for index, label in enumerate(plt.gca().yaxis.get_ticklabels()):
    if index % 2 != 0:
        label.set_visible(False)
        
plt.savefig(PREF+'polar.png',dpi=300,bbox_inches=0,pad=0,transparent=True)

# %%
fig=plt.figure(figsize=[10,8])
plt.subplot(211)
plt.plot(df.delay.values,df.gamma.values,'-r.',label='$\gamma$',lw=2)
plt.legend()
plt.subplot(212)
plt.plot(df.delay.values,df.theta.values,'-g.',label='$\omega$',lw=2)
plt.legend()
plt.savefig(PREF+'gammaomega.png',dpi=300,bbox_inches=0,pad=0,transparent=True)

df1=df.set_index('delay').ewm(alpha=.001).mean()
df.set_index('delay').ewm(alpha=.001).mean().plot()
plt.savefig(PREF+'gammaomega_.png',dpi=300,bbox_inches=0,pad=0,transparent=True)       


fig=plt.figure(figsize=[10,25])
ax = plt.subplot(111, projection='polar')
sf=plt.scatter(2*df1.theta.values**1,df1.gamma.values,c=df1.index.values,s=70,cmap='Spectral_r',alpha=.5)
plt.colorbar(sf, fraction=0.046, pad=0.04)
ax.set_ylim(0,1.1*df1.gamma.max())
for index, label in enumerate(plt.gca().yaxis.get_ticklabels()):
    if index % 2 != 0:
        label.set_visible(False)
plt.savefig(PREF+'polar_.png',dpi=300,bbox_inches=0,pad=0,transparent=True)
